# %%
import pandas as pd
import numpy as np
from time import time
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
output = open('data_plc.pkl', 'wb')

customer = pd.read_csv("CustomerList2.txt",sep='\t')
customerProfile = pd.read_csv("CustomerProfiles.txt",sep='\t')
# when saving, specify the DPI
# customer.groupby('accounttype').annualvolume.describe()
#customer.groupby('accounttype').annualvolume.mean().plot(kind='bar', title="Scores", rot=0)
customerProfile.head()
customerProfile.describe()
# Out:
#         commodityid   meternumber             1             2             3  \
# count  19020.000000  19021.000000  19021.000000  19020.000000  19020.000000
# mean      28.435017     27.332545     22.437530     18.513811     20.525242
# std       32.801405     31.715322     24.317929     18.813966     22.294932
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        5.033333      5.471591      4.243971      2.645185      1.033333
# 50%       18.459334     17.121245     15.995996     14.605606     16.881831
# 75%       39.425531     37.392408     31.352549     27.929608     32.292533
# max      817.296296    843.112069    428.268817    336.000000    460.467742
#
#                   4             5             6             7             8  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      25.439463     28.790474     26.989899     22.531940     18.756153
# ...

# %%
data = customerProfile.ix[:,7:17]

# %%
from sklearn.cluster import KMeans
a=[]
for i in range(1,11,1):
    km = KMeans(i)
    km.fit(data.dropna())
    km.cluster_centers_
    a.append(km.inertia_)

# %%
a = [19678063.408257138,20629361.025314219,21766790.807679027,23207586.033384617,25128961.999902584,27916396.942853294,31911292.176180556,38900298.01137571,56172911.026800729,120166975.08456247]

# %%
km = KMeans(4)
km.fit(data.dropna())
a = km.cluster_centers_
for i in a:
    print list(i)
# Out:
# [49.284095986548721, 40.159312556773429, 44.283772792891014, 54.185784138688618, 60.293691651397175, 56.876953452872911, 47.91250225726899, 40.532793800204075, 45.786786031543571, 57.842801579589505]
# [4.7109472435012485, 3.2735038258827576, 2.2459080276347798, 2.2926823999360693, 2.4983787243805295, 2.3772294492668706, 2.1307434059362329, 2.2219924923653913, 3.0636180761576171, 4.2529219824225066]
# [88.494749163634594, 73.487420357540415, 84.697961257942339, 100.04854923684627, 112.60436173211539, 103.6797771803943, 89.319936852286489, 74.930603233255795, 82.71617918392117, 108.53777652515387]
# [22.905311481743244, 19.925079753434581, 23.688029380818488, 30.783272405998485, 35.628409702232616, 33.29342027189881, 27.133177171195918, 21.593631099281783, 21.982064015361026, 25.498634597581386]

# %%
plt.plot(a)
plt.show()

# %%
a1 =[49.284095986548721, 40.159312556773429, 44.283772792891014, 54.185784138688618, 60.293691651397175, 56.876953452872911, 47.91250225726899, 40.532793800204075, 45.786786031543571, 57.842801579589505]
a2 =[4.7109472435012485, 3.2735038258827576, 2.2459080276347798, 2.2926823999360693, 2.4983787243805295, 2.3772294492668706, 2.1307434059362329, 2.2219924923653913, 3.0636180761576171, 4.2529219824225066]
a3 = [88.494749163634594, 73.487420357540415, 84.697961257942339, 100.04854923684627, 112.60436173211539, 103.6797771803943, 89.319936852286489, 74.930603233255795, 82.71617918392117, 108.53777652515387]
a4 = [22.905311481743244, 19.925079753434581, 23.688029380818488, 30.783272405998485, 35.628409702232616, 33.29342027189881, 27.133177171195918, 21.593631099281783, 21.982064015361026, 25.498634597581386]
dic = [a1,a2,a3,a4]
